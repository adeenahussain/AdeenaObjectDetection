# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\hp\anaconda3\lib\site-packages (8.3.5)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.24.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from ultralytics import YOLO

# Load the model
yolo = YOLO('yolov8s.pt')

# Load the video capture
videoCap = cv2.VideoCapture(0)

# Function to get class colors
def getColours(cls_num):
    base_colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]
    color_index = cls_num % len(base_colors)
    increments = [(1, -2, 1), (-2, 1, -1), (1, -1, 2)]
    color = [base_colors[color_index][i] + increments[color_index][i] * 
    (cls_num // len(base_colors)) % 256 for i in range(3)]
    return tuple(color)

while True:
    ret, frame = videoCap.read()
    if not ret:
        continue
    results = yolo.track(frame, stream=True)

    for result in results:
        # Get the classes names
        classes_names = result.names

        # Iterate over each box
        for box in result.boxes:
            # Check if confidence is greater than 40 percent
            if box.conf[0] > 0.4:
                # Get coordinates
                [x1, y1, x2, y2] = box.xyxy[0]
                # Convert to int
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                # Get the class
                cls = int(box.cls[0])

                # Get the class name
                class_name = classes_names[cls]

                # Get the respective colour
                colour = getColours(cls)

                # Draw the rectangle
                cv2.rectangle(frame, (x1, y1), (x2, y2), colour, 2)

                # Put the class name and confidence on the image
                cv2.putText(frame, f'{classes_names[int(box.cls[0])]} {box.conf[0]:.2f}', (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 1, colour, 2)

    # Create a purple border
    border_size = 20  # Set the size of the border
    bordered_frame = cv2.copyMakeBorder(frame, border_size, border_size, border_size, border_size, cv2.BORDER_CONSTANT, value=(128, 0, 128))  # Purple border

    # Show the image with border
    cv2.imshow('ObjectDetection', bordered_frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and destroy all windows
videoCap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1 chair, 1 laptop, 676.8ms
# Speed: 26.6ms preprocess, 676.8ms inference, 17.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 437.1ms
# Speed: 6.8ms preprocess, 437.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 hot dog, 1 bed, 413.6ms
# Speed: 3.0ms preprocess, 413.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 361.4ms
# Speed: 2.5ms preprocess, 361.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 361.7ms
# Speed: 2.5ms preprocess, 361.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 350.9ms
# Speed: 2.8ms preprocess, 350.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 336.5ms
# Speed: 2.9ms preprocess, 336.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 339.0ms
# Speed: 3.2ms preprocess, 339.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 341.6ms
# Speed: 4.1ms preprocess, 341.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 361.9ms
# Speed: 3.0ms preprocess, 361.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 331.2ms
# Speed: 3.3ms preprocess, 331.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 329.1ms
# Speed: 5.0ms preprocess, 329.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 324.6ms
# Speed: 2.0ms preprocess, 324.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.8ms
# Speed: 2.6ms preprocess, 327.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.2ms
# Speed: 4.0ms preprocess, 324.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 ties, 1 bed, 323.6ms
# Speed: 3.1ms preprocess, 323.6ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.3ms
# Speed: 3.0ms preprocess, 324.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.1ms
# Speed: 3.0ms preprocess, 330.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.9ms
# Speed: 2.6ms preprocess, 324.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 328.0ms
# Speed: 2.0ms preprocess, 328.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.9ms
# Speed: 2.6ms preprocess, 320.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.7ms
# Speed: 2.0ms preprocess, 322.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.6ms
# Speed: 2.9ms preprocess, 326.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.7ms
# Speed: 3.0ms preprocess, 326.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.9ms
# Speed: 5.0ms preprocess, 319.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.2ms
# Speed: 5.1ms preprocess, 327.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.7ms
# Speed: 3.0ms preprocess, 325.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 329.9ms
# Speed: 4.0ms preprocess, 329.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.9ms
# Speed: 3.0ms preprocess, 325.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 339.8ms
# Speed: 5.0ms preprocess, 339.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bed, 323.3ms
# Speed: 2.0ms preprocess, 323.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.1ms
# Speed: 2.0ms preprocess, 325.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person,
9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 381.4ms
# Speed: 3.0ms preprocess, 381.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 385.2ms
# Speed: 2.0ms preprocess, 385.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 381.2ms
# Speed: 2.6ms preprocess, 381.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 378.4ms
# Speed: 5.5ms preprocess, 378.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 386.1ms
# Speed: 6.2ms preprocess, 386.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 384.5ms
# Speed: 2.0ms preprocess, 384.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 381.8ms
# Speed: 3.0ms preprocess, 381.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bowl, 386.5ms
# Speed: 3.1ms preprocess, 386.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 386.4ms
# Speed: 3.1ms preprocess, 386.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 385.7ms
# Speed: 3.0ms preprocess, 385.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 386.9ms
# Speed: 2.0ms preprocess, 386.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 383.2ms
# Speed: 3.0ms preprocess, 383.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 387.0ms
# Speed: 3.0ms preprocess, 387.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bowl, 1 sandwich, 1 hot dog, 1 chair, 386.1ms
# Speed: 13.3ms preprocess, 386.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 387.3ms
# Speed: 5.9ms preprocess, 387.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 379.3ms
# Speed: 3.0ms preprocess, 379.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 390.3ms
# Speed: 3.3ms preprocess, 390.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 382.7ms
# Speed: 3.0ms preprocess, 382.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 387.4ms
# Speed: 2.5ms preprocess, 387.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 382.5ms
# Speed: 3.0ms preprocess, 382.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 436.7ms
# Speed: 2.1ms preprocess, 436.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 434.5ms
# Speed: 3.0ms preprocess, 434.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 421.4ms
# Speed: 4.2ms preprocess, 421.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 405.4ms
# Speed: 4.0ms preprocess, 405.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 400.0ms
# Speed: 5.0ms preprocess, 400.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 444.1ms
# Speed: 11.1ms preprocess, 444.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 451.1ms
# Speed: 4.7ms preprocess, 451.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 407.2ms
# Speed: 3.0ms preprocess, 407.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 449.1ms
# Speed: 2.6ms preprocess, 449.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 443.0ms
# Speed: 4.1ms preprocess, 443.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 426.1ms
# Speed: 3.0ms preprocess, 426.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 436.2ms
# Speed: 4.0ms preprocess, 436.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 404.7ms
# Speed: 3.1ms preprocess, 404.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 472.9ms
# Speed: 3.1ms preprocess, 472.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 501.8ms
# Speed: 3.3ms preprocess, 501.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 519.0ms
# Speed: 3.8ms preprocess, 519.0ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 484.2ms
# Speed: 4.0ms preprocess, 484.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 467.3ms
# Speed: 3.8ms preprocess, 467.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 449.2ms
# Speed: 3.0ms preprocess, 449.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      22     continue
#      23 results = yolo.track(frame, stream=True)
# ---> 25 for result in results:
#      26     # Get the classes names
#      27     classes_names = result.names
#      29     # Iterate over each box
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:111, in BaseModel.forward(self, x, *args, **kwargs)
#     109 if isinstance(x, dict):  # for cases of training and validating while training.
#     110     return self.loss(x, *args, **kwargs)
# --> 111 return self.predict(x, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:129, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     127 if augment:
#     128     return self._predict_augment(x)
# --> 129 return self._predict_once(x, profile, visualize, embed)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:150, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     148 if profile:
#     149     self._profile_one_layer(m, x, dt)
# --> 150 x = m(x)  # run
#     151 y.append(x if m.i in self.save else None)  # save output
#     152 if visualize:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\modules\head.py:64, in Detect.forward(self, x)
#      61     return self.forward_end2end(x)
#      63 for i in range(self.nl):
# ---> 64     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      65 if self.training:  # Training path
#      66     return x
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
